# %%
import os
import cv2 as cv
import matplotlib.pyplot as plt

images = [lists for lists in os.listdir("/Users/rohithr/Desktop/Image-Captioning-Using-LSTM/Dataset/Images")if lists.endswith('.jpg') or lists.endswith('.jpeg') or lists.endswith('.png')]

for image in images[:5]:
    img = cv.imread(os.path.join("/Users/rohithr/Desktop/Image-Captioning-Using-LSTM/Dataset/Images",image),cv.IMREAD_GRAYSCALE)
 

    plt.imshow(img,cmap = 'gray')
    plt.show()
